# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import statsmodels.api 
import seaborn as sns
import matplotlib.pyplot as plt
#from pandas_profiling import ProfileReport
from statsmodels.formula.api import ols
from scipy import stats
from scipy.stats import norm
import statsmodels.api as sm
#from imblearn.ensemble import BalancedRandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV,train_test_split,cross_val_score,StratifiedKFold,learning_curve
from sklearn.metrics import classification_report,f1_score, recall_score, precision_score, accuracy_score
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, LabelEncoder, OrdinalEncoder, StandardScaler
from sklearn.svm import SVC
# %matplotlib inline
import os
os.chdir(r'C:\Users\manee\OneDrive\GMAT Documents\Fall 2022 Semester\Predictive Analytics 6337\project')

# %%
# --- Functions ---


# Plot learning curve
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Validation score")

    plt.legend(loc="best")
    return plt

# %%
df = pd.read_csv('telecom_customer_churn.csv')

# %%
df = df.drop(['Customer ID','Zip Code','Latitude','Longitude','City', 'Churn Category', 'Churn Reason'],axis=1)
df['Customer Status'] = np.where(df['Customer Status'] == "Churned", 1,0)

# %%
df
# Out:
#       Gender  Age Married  Number of Dependents  Number of Referrals  \
# 0     Female   37     Yes                     0                    2
# 1       Male   46      No                     0                    0
# 2       Male   50      No                     0                    0
# 3       Male   78     Yes                     0                    1
# 4     Female   75     Yes                     0                    3
# ...      ...  ...     ...                   ...                  ...
# 7038  Female   20      No                     0                    0
# 7039    Male   40     Yes                     0                    1
# 7040    Male   22      No                     0                    0
# 7041    Male   21     Yes                     0                    5
# 7042    Male   36     Yes                     0                    1
#
#       Tenure in Months    Offer Phone Service  \
# 0                    9     None           Yes
# 1                    9     None           Yes
# 2                    4  Offer E           Yes
# 3                   13  Offer D           Yes
# 4                    3     None           Yes
# ...                ...      ...           ...
# 7038                13  Offer D           Yes
# 7039                22  Offer D           Yes
# 7040                 2  Offer E           Yes
# 7041                67  Offer A           Yes
# 7042                63     None            No
#
#       Avg Monthly Long Distance Charges Multiple Lines  ...   Payment Method  \
# 0                                 42.39             No  ...      Credit Card
# 1                                 10.69            Yes  ...      Credit Card
# 2                                 33.65             No  ...  Bank Withdrawal
# 3                                 27.82             No  ...  Bank Withdrawal
# 4                                  7.38             No  ...      Credit Card
# ...                                 ...            ...  ...              ...
# 7038                              46.68             No  ...      Credit Card
# 7039                              16.20            Yes  ...  Bank Withdrawal
# 7040                              18.62             No  ...      Credit Card
# 7041                               2.12             No  ...      Credit Card
# 7042                                NaN            NaN  ...  Bank Withdrawal
#
#      Monthly Charge  Total Charges Total Refunds Total Extra Data Charges  \
# 0             65.60         593.30          0.00                        0
# 1             -4.00         542.40         38.33                       10
# 2             73.90         280.85          0.00                        0
# 3             98.00        1237.85          0.00                        0
# 4             83.90         267.40          0.00                        0
# ...             ...            ...           ...                      ...
# 7038          55.15         742.90          0.00                        0
# 7039          85.10        1873.70          0.00                        0
# 7040          50.30          92.75          0.00                        0
# 7041          67.85        4627.65          0.00                        0
# 7042          59.00        3707.60          0.00                        0
#
#      Total Long Distance Charges Total Revenue Customer Status  \
# 0                         381.51        974.81               0
# 1                          96.21        610.28               0
# 2                         134.60        415.45               1
# 3                         361.66       1599.51               1
# 4                          22.14        289.54               1
# ...                          ...           ...             ...
# 7038                      606.84       1349.74               0
# 7039                      356.40       2230.10               1
# 7040                       37.24        129.99               0
# 7041                      142.04       4769.69               0
# 7042                        0.00       3707.60               0
#
#               Unnamed: 38 Unnamed: 39
# 0                     NaN         NaN
# 1             total cells    267634.0
# 2     missing value cells         NaN
# 3                     NaN         NaN
# 4                     NaN         NaN
# ...                   ...         ...
# 7038                  NaN         NaN
# 7039                  NaN         NaN
# 7040                  NaN         NaN
# 7041                  NaN         NaN
# 7042                  NaN         NaN
#
# [7043 rows x 33 columns]

# %%
# --- Replacing Nan values according to the EDA ---

df[['Internet Type', 'Online Security', 'Online Backup', 'Device Protection Plan', 
           'Premium Tech Support', 'Streaming TV', 'Streaming Movies','Streaming Music','Unlimited Data']] = df[['Internet Type', 'Online Security', 'Online Backup', 'Device Protection Plan', 
           'Premium Tech Support', 'Streaming TV', 'Streaming Movies','Streaming Music','Unlimited Data']].replace(np.nan,'No')
df['Avg Monthly GB Download'] = df['Avg Monthly GB Download'].replace(np.nan,0.0)
df['Multiple Lines'] = df['Multiple Lines'].replace(np.nan,'No')
df['Avg Monthly Long Distance Charges'] = df['Avg Monthly Long Distance Charges'].replace(np.nan,0.0)

# %%
df = df[df['Monthly Charge'] >= 0]

# %%
# --- Data Set splitting ---
X = df.drop('Customer Status',axis=1)
y = df['Customer Status']
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,stratify=y,random_state=321) #scikit learn

# %%
pd.Series({c: df.select_dtypes('object')[c].unique() for c in df.select_dtypes('object')})
# Out:
# Gender                                                       [Female, Male]
# Married                                                           [Yes, No]
# Offer                     [None, Offer E, Offer D, Offer A, Offer B, Off...
# Phone Service                                                     [Yes, No]
# Multiple Lines                                                    [No, Yes]
# Internet Service                                                  [Yes, No]
# Internet Type                                 [Cable, Fiber Optic, DSL, No]
# Online Security                                                   [No, Yes]
# Online Backup                                                     [Yes, No]
# Device Protection Plan                                            [No, Yes]
# Premium Tech Support                                              [Yes, No]
# Streaming TV                                                      [Yes, No]
# Streaming Movies                                                  [No, Yes]
# Streaming Music                                                   [No, Yes]
# Unlimited Data                                                    [Yes, No]
# Contract                               [One Year, Month-to-Month, Two Year]
# Paperless Billing                                                 [Yes, No]
# Payment Method                 [Credit Card, Bank Withdrawal, Mailed Check]
# Unnamed: 38                         [nan, total cells, missing value cells]
# dtype: object

# %%
#--- Label encoding the Ordinal Internet Type Variable ---
ord_encoder = LabelEncoder()
X_train['Internet Type'] = ord_encoder.fit_transform(X_train['Internet Type'])
X_test['Internet Type'] = ord_encoder.transform(X_test['Internet Type'])
# Out:
# C:\Users\manee\AppData\Local\Temp/ipykernel_31420/2595729545.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Internet Type'] = ord_encoder.fit_transform(X_train['Internet Type'])
# C:\Users\manee\AppData\Local\Temp/ipykernel_31420/2595729545.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Internet Type'] = ord_encoder.transform(X_test['Internet Type'])

# %%
#--- Standardizing numeric columns ---
num_col = X_train.select_dtypes('number').columns
std_scaler = StandardScaler()
X_train[num_col] = std_scaler.fit_transform(X_train[num_col])
X_test[num_col] = std_scaler.transform(X_test[num_col])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)

# %%
#--- one hot encoding non ordinal features ---
oh_col = X.select_dtypes('object').drop('Internet Type',axis=1).columns #object columns to be one hot encoded 

oh_encoder = OneHotEncoder(sparse=False)
OH_encoded_train_features = oh_encoder.fit_transform(X_train[oh_col])
OH_encoded_X_train = pd.DataFrame(data=OH_encoded_train_features,index=X_train[oh_col].index,columns=oh_encoder.get_feature_names(X_train[oh_col].columns))

OH_encoded_test_features = oh_encoder.transform(X_test[oh_col])
OH_encoded_X_test = pd.DataFrame(data=OH_encoded_test_features,index=X_test[oh_col].index,columns=oh_encoder.get_feature_names(X_test[oh_col].columns))

# %%
X_train = pd.concat([X_train,OH_encoded_X_train],axis=1)
X_train = X_train.drop(X_train[oh_col],axis=1)
X_test = pd.concat([X_test,OH_encoded_X_test],axis=1)
X_test = X_test.drop(X_test[oh_col],axis=1)

# %%
X_train['Internet Type']
# Out:
# 4044    1.347971
# 1008    0.265293
# 3954    0.265293
# 1696    0.265293
# 2022    0.265293
#           ...
# 6391   -1.900062
# 399     1.347971
# 1844   -0.817384
# 2996   -0.817384
# 5866    0.265293
# Name: Internet Type, Length: 5538, dtype: float64

# %%
X_train = X_train.drop(['Gender_Female', 'Married_No', 'Offer_None', 'Phone Service_No', 'Multiple Lines_No', 
              'Internet Service_No','Online Security_No', 'Online Backup_No',
              'Device Protection Plan_No', 'Premium Tech Support_No', 'Streaming TV_No',
             'Streaming Movies_No','Streaming Music_No','Unlimited Data_No', 
              'Contract_Month-to-Month', 'Paperless Billing_No','Payment Method_Bank Withdrawal'],axis=1)

# %%
X_test = X_test.drop(['Gender_Female', 'Married_No', 'Offer_None', 'Phone Service_No', 'Multiple Lines_No', 
              'Internet Service_No','Online Security_No', 'Online Backup_No',
              'Device Protection Plan_No', 'Premium Tech Support_No', 'Streaming TV_No',
             'Streaming Movies_No','Streaming Music_No','Unlimited Data_No', 
              'Contract_Month-to-Month', 'Paperless Billing_No','Payment Method_Bank Withdrawal'],axis=1)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5538 entries, 4044 to 5866
# Data columns (total 36 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                5538 non-null   float64
#  1   Number of Dependents               5538 non-null   float64
#  2   Number of Referrals                5538 non-null   float64
#  3   Tenure in Months                   5538 non-null   float64
#  4   Avg Monthly Long Distance Charges  5538 non-null   float64
#  5   Internet Type                      5538 non-null   float64
#  6   Avg Monthly GB Download            5538 non-null   float64
#  7   Monthly Charge                     5538 non-null   float64
#  8   Total Charges                      5538 non-null   float64
#  9   Total Refunds                      5538 non-null   float64
#  10  Total Extra Data Charges           5538 non-null   float64
#  11  Total Long Distance Charges        5538 non-null   float64
#  12  Total Revenue                      5538 non-null   float64
#  13  Gender_Male                        5538 non-null   float64
#  14  Married_Yes                        5538 non-null   float64
#  15  Offer_Offer A                      5538 non-null   float64
#  16  Offer_Offer B                      5538 non-null   float64
#  17  Offer_Offer C                      5538 non-null   float64
#  18  Offer_Offer D                      5538 non-null   float64
#  19  Offer_Offer E                      5538 non-null   float64
#  20  Phone Service_Yes                  5538 non-null   float64
#  21  Multiple Lines_Yes                 5538 non-null   float64
#  22  Internet Service_Yes               5538 non-null   float64
#  23  Online Security_Yes                5538 non-null   float64
#  24  Online Backup_Yes                  5538 non-null   float64
#  25  Device Protection Plan_Yes         5538 non-null   float64
#  26  Premium Tech Support_Yes           5538 non-null   float64
#  27  Streaming TV_Yes                   5538 non-null   float64
#  28  Streaming Movies_Yes               5538 non-null   float64
#  29  Streaming Music_Yes                5538 non-null   float64
#  30  Unlimited Data_Yes                 5538 non-null   float64
#  31  Contract_One Year                  5538 non-null   float64
#  32  Contract_Two Year                  5538 non-null   float64
#  33  Paperless Billing_Yes              5538 non-null   float64
#  34  Payment Method_Credit Card         5538 non-null   float64
#  35  Payment Method_Mailed Check        5538 non-null   float64
# dtypes: float64(36)
# memory usage: 1.6 MB

# %%
X_train
# Out:
#            Age  Number of Dependents  Number of Referrals  Tenure in Months  \
# 4044  1.936083             -0.489690            -0.651232          1.567675
# 1008  0.864035             -0.489690             0.348544          0.792862
# 3954  1.400059             -0.489690            -0.317974         -1.205341
# 1696  1.757408             -0.489690            -0.317974          0.303506
# 2022 -0.624920             -0.489690            -0.651232         -1.164562
# ...        ...                   ...                  ...               ...
# 6391 -0.446246              1.576522             1.015061          1.282217
# 399  -0.684478              2.609628            -0.317974         -0.797545
# 1844 -1.458735             -0.489690            -0.651232         -1.083002
# 2996  1.757408              2.609628             0.015285         -0.185850
# 5866  1.161826             -0.489690            -0.651232         -0.675206
#
#       Avg Monthly Long Distance Charges  Internet Type  \
# 4044                          -1.175492       1.347971
# 1008                          -0.320485       0.265293
# 3954                           0.600242       0.265293
# 1696                          -1.297912       0.265293
# 2022                           0.070615       0.265293
# ...                                 ...            ...
# 6391                           0.238781      -1.900062
# 399                            1.108607       1.347971
# 1844                          -1.277938      -0.817384
# 2996                          -1.481542      -0.817384
# 5866                           0.587356       0.265293
#
#       Avg Monthly GB Download  Monthly Charge  Total Charges  Total Refunds  \
# 4044                -0.999584       -1.317644      -0.223864      -0.250568
# 1008                -0.853534        0.897381       1.039849      -0.250568
# 3954                 0.314869        0.996635      -0.880754      -0.250568
# 1696                -0.853534        1.236500       0.800671      -0.250568
# 2022                -0.171966        0.402764      -0.856880      -0.250568
# ...                       ...             ...            ...            ...
# 6391                -0.171966        0.043794       0.792588       3.217249
# 399                 -0.999584       -1.476450      -0.892923      -0.250568
# 1844                 0.996437       -0.290362      -0.855975      -0.250568
# 2996                 0.022768       -0.839569      -0.519866      -0.250568
# 5866                -0.318016        1.056188      -0.305821       5.639356
#
#       ...  Premium Tech Support_Yes  Streaming TV_Yes  Streaming Movies_Yes  \
# 4044  ...                       0.0               0.0                   0.0
# 1008  ...                       1.0               0.0                   0.0
# 3954  ...                       0.0               1.0                   1.0
# 1696  ...                       0.0               1.0                   1.0
# 2022  ...                       0.0               0.0                   0.0
# ...   ...                       ...               ...                   ...
# 6391  ...                       1.0               1.0                   0.0
# 399   ...                       0.0               0.0                   0.0
# 1844  ...                       0.0               0.0                   0.0
# 2996  ...                       0.0               0.0                   1.0
# 5866  ...                       0.0               1.0                   1.0
#
#       Streaming Music_Yes  Unlimited Data_Yes  Contract_One Year  \
# 4044                  0.0                 0.0                0.0
# 1008                  0.0                 0.0                0.0
# 3954                  0.0                 1.0                0.0
# 1696                  0.0                 1.0                0.0
# 2022                  0.0                 1.0                0.0
# ...                   ...                 ...                ...
# 6391                  0.0                 0.0                1.0
# 399                   0.0                 0.0                0.0
# 1844                  0.0                 1.0                0.0
# 2996                  1.0                 1.0                1.0
# 5866                  0.0                 1.0                0.0
#
#       Contract_Two Year  Paperless Billing_Yes  Payment Method_Credit Card  \
# 4044                1.0                    1.0                         1.0
# 1008                1.0                    1.0                         1.0
# 3954                0.0                    1.0                         0.0
# 1696                0.0                    0.0                         0.0
# 2022                0.0                    1.0                         0.0
# ...                 ...                    ...                         ...
# 6391                0.0                    0.0                         0.0
# 399                 0.0                    1.0                         1.0
# 1844                0.0                    1.0                         0.0
# 2996                0.0                    1.0                         0.0
# 5866                0.0                    1.0                         0.0
#
#       Payment Method_Mailed Check
# 4044                          0.0
# 1008                          0.0
# 3954                          0.0
# 1696                          0.0
# 2022                          0.0
# ...                           ...
# 6391                          1.0
# 399                           0.0
# 1844                          0.0
# 2996                          0.0
# 5866                          0.0
#
# [5538 rows x 36 columns]

# %%
x = sm.add_constant(X_train)
x
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
#       const       Age  Number of Dependents  Number of Referrals  \
# 4044    1.0  1.936083             -0.489690            -0.651232
# 1008    1.0  0.864035             -0.489690             0.348544
# 3954    1.0  1.400059             -0.489690            -0.317974
# 1696    1.0  1.757408             -0.489690            -0.317974
# 2022    1.0 -0.624920             -0.489690            -0.651232
# ...     ...       ...                   ...                  ...
# 6391    1.0 -0.446246              1.576522             1.015061
# 399     1.0 -0.684478              2.609628            -0.317974
# 1844    1.0 -1.458735             -0.489690            -0.651232
# 2996    1.0  1.757408              2.609628             0.015285
# 5866    1.0  1.161826             -0.489690            -0.651232
#
#       Tenure in Months  Avg Monthly Long Distance Charges  Internet Type  \
# 4044          1.567675                          -1.175492       1.347971
# 1008          0.792862                          -0.320485       0.265293
# 3954         -1.205341                           0.600242       0.265293
# 1696          0.303506                          -1.297912       0.265293
# 2022         -1.164562                           0.070615       0.265293
# ...                ...                                ...            ...
# 6391          1.282217                           0.238781      -1.900062
# 399          -0.797545                           1.108607       1.347971
# 1844         -1.083002                          -1.277938      -0.817384
# 2996         -0.185850                          -1.481542      -0.817384
# 5866         -0.675206                           0.587356       0.265293
#
#       Avg Monthly GB Download  Monthly Charge  Total Charges  ...  \
# 4044                -0.999584       -1.317644      -0.223864  ...
# 1008                -0.853534        0.897381       1.039849  ...
# 3954                 0.314869        0.996635      -0.880754  ...
# 1696                -0.853534        1.236500       0.800671  ...
# 2022                -0.171966        0.402764      -0.856880  ...
# ...                       ...             ...            ...  ...
# 6391                -0.171966        0.043794       0.792588  ...
# 399                 -0.999584       -1.476450      -0.892923  ...
# 1844                 0.996437       -0.290362      -0.855975  ...
# 2996                 0.022768       -0.839569      -0.519866  ...
# 5866                -0.318016        1.056188      -0.305821  ...
#
#       Premium Tech Support_Yes  Streaming TV_Yes  Streaming Movies_Yes  \
# 4044                       0.0               0.0                   0.0
# 1008                       1.0               0.0                   0.0
# 3954                       0.0               1.0                   1.0
# 1696                       0.0               1.0                   1.0
# 2022                       0.0               0.0                   0.0
# ...                        ...               ...                   ...
# 6391                       1.0               1.0                   0.0
# 399                        0.0               0.0                   0.0
# 1844                       0.0               0.0                   0.0
# 2996                       0.0               0.0                   1.0
# 5866                       0.0               1.0                   1.0
#
#       Streaming Music_Yes  Unlimited Data_Yes  Contract_One Year  \
# 4044                  0.0                 0.0                0.0
# 1008                  0.0                 0.0                0.0
# 3954                  0.0                 1.0                0.0
# 1696                  0.0                 1.0                0.0
# 2022                  0.0                 1.0                0.0
# ...                   ...                 ...                ...
# 6391                  0.0                 0.0                1.0
# 399                   0.0                 0.0                0.0
# 1844                  0.0                 1.0                0.0
# 2996                  1.0                 1.0                1.0
# 5866                  0.0                 1.0                0.0
#
#       Contract_Two Year  Paperless Billing_Yes  Payment Method_Credit Card  \
# 4044                1.0                    1.0                         1.0
# 1008                1.0                    1.0                         1.0
# 3954                0.0                    1.0                         0.0
# 1696                0.0                    0.0                         0.0
# 2022                0.0                    1.0                         0.0
# ...                 ...                    ...                         ...
# 6391                0.0                    0.0                         0.0
# 399                 0.0                    1.0                         1.0
# 1844                0.0                    1.0                         0.0
# 2996                0.0                    1.0                         0.0
# 5866                0.0                    1.0                         0.0
#
#       Payment Method_Mailed Check
# 4044                          0.0
# 1008                          0.0
# 3954                          0.0
# 1696                          0.0
# 2022                          0.0
# ...                           ...
# 6391                          1.0
# 399                           0.0
# 1844                          0.0
# 2996                          0.0
# 5866                          0.0
#
# [5538 rows x 37 columns]

# %%
x = sm.add_constant(X_train)

#fit regression model
model = sm.OLS(y_train, x).fit()
print(model.summary())
#view summary of model fit
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Customer Status   R-squared:                       0.365
# Model:                            OLS   Adj. R-squared:                  0.361
# Method:                 Least Squares   F-statistic:                     90.41
# Date:                Tue, 29 Nov 2022   Prob (F-statistic):               0.00
# Time:                        03:01:19   Log-Likelihood:                -2074.3
# No. Observations:                5538   AIC:                             4221.
# Df Residuals:                    5502   BIC:                             4459.
# Df Model:                          35
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                                 0.8401      0.081     10.426      0.000       0.682       0.998
# Age                                   0.0333      0.006      5.481      0.000       0.021       0.045
# Number of Dependents                 -0.0465      0.005     -8.773      0.000      -0.057      -0.036
# Number of Referrals                  -0.0920      0.007    -14.023      0.000      -0.105      -0.079
# Tenure in Months                  -2.422e-05      0.014     -0.002      0.999      -0.028       0.028
# Avg Monthly Long Distance Charges    -0.0204      0.008     -2.401      0.016      -0.037      -0.004
# Internet Type                        -0.0588      0.013     -4.394      0.000      -0.085      -0.033
# Avg Monthly GB Download              -0.0015      0.007     -0.227      0.821      -0.015       0.012
# Monthly Charge                        0.3147      0.028     11.237      0.000       0.260       0.370
# Total Charges                        -0.0908      0.010     -8.737      0.000      -0.111      -0.070
# Total Refunds                        -0.0096      0.005     -2.019      0.044      -0.019      -0.000
# Total Extra Data Charges             -0.0023      0.008     -0.301      0.763      -0.017       0.013
# Total Long Distance Charges           0.0456      0.011      4.177      0.000       0.024       0.067
# Total Revenue                        -0.0581      0.007     -8.032      0.000      -0.072      -0.044
# Gender_Male                          -0.0030      0.010     -0.311      0.756      -0.022       0.016
# Married_Yes                           0.1446      0.014     10.624      0.000       0.118       0.171
# Offer_Offer A                         0.0609      0.021      2.851      0.004       0.019       0.103
# Offer_Offer B                        -0.0197      0.016     -1.197      0.231      -0.052       0.013
# Offer_Offer C                        -0.0474      0.021     -2.294      0.022      -0.088      -0.007
# Offer_Offer D                        -0.0875      0.018     -4.858      0.000      -0.123      -0.052
# Offer_Offer E                         0.0739      0.017      4.282      0.000       0.040       0.108
# Phone Service_Yes                    -0.2257      0.030     -7.648      0.000      -0.284      -0.168
# Multiple Lines_Yes                    0.0060      0.013      0.471      0.638      -0.019       0.031
# Internet Service_Yes                 -0.3023      0.063     -4.777      0.000      -0.426      -0.178
# Online Security_Yes                  -0.0874      0.013     -6.761      0.000      -0.113      -0.062
# Online Backup_Yes                    -0.0637      0.013     -4.994      0.000      -0.089      -0.039
# Device Protection Plan_Yes           -0.0445      0.013     -3.416      0.001      -0.070      -0.019
# Premium Tech Support_Yes             -0.0771      0.013     -5.830      0.000      -0.103      -0.051
# Streaming TV_Yes                     -0.0268      0.016     -1.683      0.092      -0.058       0.004
# Streaming Movies_Yes                 -0.0898      0.024     -3.791      0.000      -0.136      -0.043
# Streaming Music_Yes                   0.0516      0.021      2.463      0.014       0.011       0.093
# Unlimited Data_Yes                   -0.0072      0.025     -0.292      0.770      -0.056       0.041
# Contract_One Year                    -0.1973      0.014    -13.678      0.000      -0.226      -0.169
# Contract_Two Year                    -0.2309      0.016    -14.075      0.000      -0.263      -0.199
# Paperless Billing_Yes                 0.0404      0.011      3.816      0.000       0.020       0.061
# Payment Method_Credit Card           -0.0356      0.011     -3.321      0.001      -0.057      -0.015
# Payment Method_Mailed Check           0.0985      0.022      4.518      0.000       0.056       0.141
# ==============================================================================
# Omnibus:                      184.237   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              176.547
# Skew:                           0.395   Prob(JB):                     4.61e-39
# Kurtosis:                       2.623   Cond. No.                     2.25e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.57e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
y_pred = model.predict(x)
y_pred
# Out:
# 4044    0.150852
# 1008    0.159139
# 3954    0.935857
# 1696    0.632745
# 2022    0.551812
#           ...
# 6391   -0.022627
# 399     0.110931
# 1844    0.302168
# 2996    0.215535
# 5866    0.642357
# Length: 5538, dtype: float64

# %%
md = model.summary()
md
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Customer Status   R-squared:                       0.365
# Model:                            OLS   Adj. R-squared:                  0.361
# Method:                 Least Squares   F-statistic:                     90.41
# Date:                Tue, 29 Nov 2022   Prob (F-statistic):               0.00
# Time:                        03:01:20   Log-Likelihood:                -2074.3
# No. Observations:                5538   AIC:                             4221.
# Df Residuals:                    5502   BIC:                             4459.
# Df Model:                          35
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                                 0.8401      0.081     10.426      0.000       0.682       0.998
# Age                                   0.0333      0.006      5.481      0.000       0.021       0.045
# Number of Dependents                 -0.0465      0.005     -8.773      0.000      -0.057      -0.036
# Number of Referrals                  -0.0920      0.007    -14.023      0.000      -0.105      -0.079
# Tenure in Months                  -2.422e-05      0.014     -0.002      0.999      -0.028       0.028
# Avg Monthly Long Distance Charges    -0.0204      0.008     -2.401      0.016      -0.037      -0.004
# Internet Type                        -0.0588      0.013     -4.394      0.000      -0.085      -0.033
# Avg Monthly GB Download              -0.0015      0.007     -0.227      0.821      -0.015       0.012
# Monthly Charge                        0.3147      0.028     11.237      0.000       0.260       0.370
# Total Charges                        -0.0908      0.010     -8.737      0.000      -0.111      -0.070
# Total Refunds                        -0.0096      0.005     -2.019      0.044      -0.019      -0.000
# Total Extra Data Charges             -0.0023      0.008     -0.301      0.763      -0.017       0.013
# Total Long Distance Charges           0.0456      0.011      4.177      0.000       0.024       0.067
# Total Revenue                        -0.0581      0.007     -8.032      0.000      -0.072      -0.044
# Gender_Male                          -0.0030      0.010     -0.311      0.756      -0.022       0.016
# Married_Yes                           0.1446      0.014     10.624      0.000       0.118       0.171
# Offer_Offer A                         0.0609      0.021      2.851      0.004       0.019       0.103
# Offer_Offer B                        -0.0197      0.016     -1.197      0.231      -0.052       0.013
# Offer_Offer C                        -0.0474      0.021     -2.294      0.022      -0.088      -0.007
# Offer_Offer D                        -0.0875      0.018     -4.858      0.000      -0.123      -0.052
# Offer_Offer E                         0.0739      0.017      4.282      0.000       0.040       0.108
# Phone Service_Yes                    -0.2257      0.030     -7.648      0.000      -0.284      -0.168
# Multiple Lines_Yes                    0.0060      0.013      0.471      0.638      -0.019       0.031
# Internet Service_Yes                 -0.3023      0.063     -4.777      0.000      -0.426      -0.178
# Online Security_Yes                  -0.0874      0.013     -6.761      0.000      -0.113      -0.062
# Online Backup_Yes                    -0.0637      0.013     -4.994      0.000      -0.089      -0.039
# Device Protection Plan_Yes           -0.0445      0.013     -3.416      0.001      -0.070      -0.019
# Premium Tech Support_Yes             -0.0771      0.013     -5.830      0.000      -0.103      -0.051
# Streaming TV_Yes                     -0.0268      0.016     -1.683      0.092      -0.058       0.004
# Streaming Movies_Yes                 -0.0898      0.024     -3.791      0.000      -0.136      -0.043
# Streaming Music_Yes                   0.0516      0.021      2.463      0.014       0.011       0.093
# Unlimited Data_Yes                   -0.0072      0.025     -0.292      0.770      -0.056       0.041
# Contract_One Year                    -0.1973      0.014    -13.678      0.000      -0.226      -0.169
# Contract_Two Year                    -0.2309      0.016    -14.075      0.000      -0.263      -0.199
# Paperless Billing_Yes                 0.0404      0.011      3.816      0.000       0.020       0.061
# Payment Method_Credit Card           -0.0356      0.011     -3.321      0.001      -0.057      -0.015
# Payment Method_Mailed Check           0.0985      0.022      4.518      0.000       0.056       0.141
# ==============================================================================
# Omnibus:                      184.237   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              176.547
# Skew:                           0.395   Prob(JB):                     4.61e-39
# Kurtosis:                       2.623   Cond. No.                     2.25e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.57e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
params = model.params
conf = model.conf_int()
conf['Odds Ratio'] = params
conf.columns = ['5%', '95%', 'Odds Ratio']
db = np.exp(conf)

# %% [markdown]
# ### Linear regression

# %%
# --- Data Set splitting ---
X= df.drop('Total Revenue',axis=1)
y = df['Total Revenue']
X_train, X_test,y_train,y_test = train_test_split(X,y,test_size =0.2)
# print the data
X_train
# Out:
#       Gender  Age Married  Number of Dependents  Number of Referrals  \
# 1281  Female   23     Yes                     3                    0
# 2664    Male   40      No                     0                    0
# 4633  Female   34      No                     0                    0
# 1404    Male   46     Yes                     2                    2
# 5091    Male   48      No                     0                    0
# ...      ...  ...     ...                   ...                  ...
# 5466    Male   57     Yes                     1                    1
# 1722  Female   38     Yes                     3                    5
# 4800    Male   64     Yes                     0                    2
# 1944  Female   25      No                     1                    0
# 2812  Female   49     Yes                     2                    5
#
#       Tenure in Months    Offer Phone Service  \
# 1281                24  Offer C           Yes
# 2664                 1     None           Yes
# 4633                16     None            No
# 1404                55     None           Yes
# 5091                 1  Offer E           Yes
# ...                ...      ...           ...
# 5466                 5     None           Yes
# 1722                35     None           Yes
# 4800                35     None           Yes
# 1944                49     None           Yes
# 2812                58  Offer B           Yes
#
#       Avg Monthly Long Distance Charges Multiple Lines  ... Unlimited Data  \
# 1281                              46.54            Yes  ...            Yes
# 2664                              16.91             No  ...             No
# 4633                               0.00             No  ...            Yes
# 1404                              24.70             No  ...             No
# 5091                              27.58             No  ...            Yes
# ...                                 ...            ...  ...            ...
# 5466                              11.54            Yes  ...            Yes
# 1722                              18.86            Yes  ...             No
# 4800                              23.85            Yes  ...             No
# 1944                              45.64             No  ...             No
# 2812                              40.74             No  ...            Yes
#
#             Contract  Paperless Billing   Payment Method Monthly Charge  \
# 1281        Two Year                 No  Bank Withdrawal          64.35
# 2664  Month-to-Month                 No      Credit Card          19.65
# 4633  Month-to-Month                Yes  Bank Withdrawal          38.90
# 1404        Two Year                 No  Bank Withdrawal          19.35
# 5091  Month-to-Month                 No  Bank Withdrawal          69.95
# ...              ...                ...              ...            ...
# 5466  Month-to-Month                Yes  Bank Withdrawal          80.15
# 1722        Two Year                 No  Bank Withdrawal          24.30
# 4800  Month-to-Month                Yes      Credit Card          91.50
# 1944        One Year                 No      Credit Card          19.45
# 2812  Month-to-Month                Yes  Bank Withdrawal          91.55
#
#      Total Charges Total Refunds Total Extra Data Charges  \
# 1281       1558.65          0.00                        0
# 2664         19.65          0.00                        0
# 4633        664.40          0.00                        0
# 1404       1153.25          0.00                        0
# 5091         69.95          0.00                        0
# ...            ...           ...                      ...
# 5466        385.00          0.00                        0
# 1722        821.60          0.00                        0
# 4800       3236.35         40.79                       90
# 1944        921.30          0.00                        0
# 2812       5511.65          0.00                        0
#
#      Total Long Distance Charges Customer Status
# 1281                     1116.96               0
# 2664                       16.91               0
# 4633                        0.00               0
# 1404                     1358.50               0
# 5091                       27.58               1
# ...                          ...             ...
# 5466                       57.70               1
# 1722                      660.10               0
# 4800                      834.75               0
# 1944                     2236.36               0
# 2812                     2362.92               0
#
# [5538 rows x 30 columns]

# %%
X_train['Gender'] = np.where(X_train['Gender'] == "Male", 1,0)
X_train['Married'] = np.where(X_train['Married'] == "Yes", 1,0)
X_train['Offer A'] = np.where(X_train['Offer'] == "Offer A", 1,0)
X_train['Offer B'] = np.where(X_train['Offer'] == "Offer B", 1,0)
X_train['Offer C'] = np.where(X_train['Offer'] == "Offer C", 1,0)
X_train['Offer E'] = np.where(X_train['Offer'] == "Offer E", 1,0)
X_train['Offer D'] = np.where(X_train['Offer'] == "Offer D", 1,0)
X_train['Multiple Lines'] = np.where(X_train['Multiple Lines'] == "Yes", 1,0)
X_train['Cable'] = np.where(X_train['Internet Type'] == "Cable", 1,0)
X_train['Fiber'] = np.where(X_train['Internet Type'] == "Fiber", 1,0)
X_train['Optic'] = np.where(X_train['Internet Type'] == "Optic", 1,0)
X_train['DSL'] = np.where(X_train['Internet Type'] == "DSL", 1,0)
X_train['Online Security'] = np.where(X_train['Online Security'] == "Yes", 1,0)
X_train['Online Backup'] = np.where(X_train['Online Backup'] == "Yes", 1,0)
X_train['Device Protection Plan'] = np.where(X_train['Device Protection Plan'] == "Yes", 1,0)
X_train['Premium Tech Support'] = np.where(X_train['Premium Tech Support'] == "Yes", 1,0)
X_train['Streaming TV'] = np.where(X_train['Streaming TV'] == "Yes", 1,0)
X_train['Streaming Movies'] = np.where(X_train['Streaming Movies'] == "Yes", 1,0)
X_train['Streaming Music'] = np.where(X_train['Streaming Music'] == "Yes", 1,0)
X_train['Streaming Movies'] = np.where(X_train['Streaming Movies'] == "Yes", 1,0)
X_train['Unlimited Data'] = np.where(X_train['Unlimited Data'] == "Yes", 1,0)
X_train['One Year'] = np.where(X_train['Contract'] == "One Year", 1,0)
X_train['Two Year'] = np.where(X_train['Contract'] == "Two Year", 1,0)
X_train['Month-to-Month'] = np.where(X_train['Contract'] == "Month-to-Month", 1,0)
X_train['Paperless Billing'] = np.where(X_train['Paperless Billing'] == "Yes", 1,0)
X_train['Credit Card'] = np.where(X_train['Payment Method'] == "Credit Card", 1,0)
X_train['Bank Withdrawal'] = np.where(X_train['Payment Method'] == "Bank Withdrawal", 1,0)
X_train['Phone Service'] = np.where(X_train['Phone Service'] == "Yes", 1,0)
X_train['Internet Service'] = np.where(X_train['Phone Service'] == "Yes", 1,0)
# Out:
# C:\Users\abdur\AppData\Local\Temp/ipykernel_31832/4012231977.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Gender'] = np.where(X_train['Gender'] == "Male", 1,0)
# C:\Users\abdur\AppData\Local\Temp/ipykernel_31832/4012231977.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Married'] = np.where(X_train['Married'] == "Yes", 1,0)
# C:\Users\abdur\AppData\Local\Temp/ipykernel_31832/4012231977.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Offer A'] = np.where(X_train['Offer'] == "Offer A", 1,0)
# C:\Users\abdur\AppData\Local\Temp/ipykernel_31832/4012231977.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Offer B'] = np.where(X_train['Offer'] == "Offer B", 1,0)
# C:\Users\abdur\AppData\Local\Temp/ipykernel_31832/4012231977.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Offer C'] = np.where(X_train['Offer'] == "Offer C", 1,0)
# C:\Users\abdur\AppData\Local\Temp/ipykernel_31832/4012231977.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Offer E'] = np.where(X_train['Offer'] == "Offer E", 1,0)
# C:\Users\abdur\AppData\Local\Temp/ipykernel_31832/4012231977.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Offer D'] = np.where(X_train['Offer'] == "Offer D", 1,0)
# C:\Users\abdur\AppData\Local\Temp/ipykernel_31832/4012231977.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Multiple Lines'] = np.where(X_train['Multiple Lines'] == "Yes", 1,0)
# C:\Users\abdur\AppData\Local\Temp/ipykernel_31832/4012231977.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Cable'] = np.where(X_train['Internet Type'] == "Cable", 1,0)
# C:\Users\abdur\AppData\Local\Temp/ipykernel_31832/4012231977.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Fiber'] = np.where(X_train['Internet Type'] == "Fiber", 1,0)
# C:\Users\abdur\AppData\Local\Temp/ipykernel_31832/4012231977.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Optic'] = np.where(X_train['Internet Type'] == "Optic", 1,0)
# C:\Users\abdur\AppData\Local\Temp/ipykernel_31832/4012231977.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['DSL'] = np.where(X_train['Internet Type'] == "DSL", 1,0)
# C:\Users\abdur\AppData\Local\Temp/ipykernel_31832/4012231977.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Online Security'] = np.where(X_train['Online Security'] == "Yes", 1,0)
# C:\Users\abdur\AppData\Local\Temp/ipykernel_31832/4012231977.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Online Backup'] = np.where(X_train['Online Backup'] == "Yes", 1,0)
# C:\Users\abdur\AppData\Local\Temp/ipykernel_31832/4012231977.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Device Protection Plan'] = np.where(X_train['Device Protection Plan'] == "Yes", 1,0)
# C:\Users\abdur\AppData\Local\Temp/ipykernel_31832/4012231977.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Premium Tech Support'] = np.where(X_train['Premium Tech Support'] == "Yes", 1,0)
# C:\Users\abdur\AppData\Local\Temp/ipykernel_31832/4012231977.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Streaming TV'] = np.where(X_train['Streaming TV'] == "Yes", 1,0)
# C:\Users\abdur\AppData\Local\Temp/ipykernel_31832/4012231977.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Streaming Movies'] = np.where(X_train['Streaming Movies'] == "Yes", 1,0)
# C:\Users\abdur\AppData\Local\Temp/ipykernel_31832/4012231977.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Streaming Music'] = np.where(X_train['Streaming Music'] == "Yes", 1,0)
# C:\Users\abdur\AppData\Local\Temp/ipykernel_31832/4012231977.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Streaming Movies'] = np.where(X_train['Streaming Movies'] == "Yes", 1,0)
# C:\Users\abdur\AppData\Local\Temp/ipykernel_31832/4012231977.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Unlimited Data'] = np.where(X_train['Unlimited Data'] == "Yes", 1,0)
# C:\Users\abdur\AppData\Local\Temp/ipykernel_31832/4012231977.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['One Year'] = np.where(X_train['Contract'] == "One Year", 1,0)
# C:\Users\abdur\AppData\Local\Temp/ipykernel_31832/4012231977.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Two Year'] = np.where(X_train['Contract'] == "Two Year", 1,0)
# C:\Users\abdur\AppData\Local\Temp/ipykernel_31832/4012231977.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Month-to-Month'] = np.where(X_train['Contract'] == "Month-to-Month", 1,0)
# C:\Users\abdur\AppData\Local\Temp/ipykernel_31832/4012231977.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Paperless Billing'] = np.where(X_train['Paperless Billing'] == "Yes", 1,0)
# C:\Users\abdur\AppData\Local\Temp/ipykernel_31832/4012231977.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Credit Card'] = np.where(X_train['Payment Method'] == "Credit Card", 1,0)
# C:\Users\abdur\AppData\Local\Temp/ipykernel_31832/4012231977.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Bank Withdrawal'] = np.where(X_train['Payment Method'] == "Bank Withdrawal", 1,0)
# C:\Users\abdur\AppData\Local\Temp/ipykernel_31832/4012231977.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Phone Service'] = np.where(X_train['Phone Service'] == "Yes", 1,0)
# C:\Users\abdur\AppData\Local\Temp/ipykernel_31832/4012231977.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Internet Service'] = np.where(X_train['Phone Service'] == "Yes", 1,0)

# %%
pd.Series({c: X_train.select_dtypes('object')[c].unique() for c in X_train.select_dtypes('object')})
# Out:
# Offer             [Offer C, None, Offer E, Offer D, Offer B, Off...
# Internet Type                         [DSL, No, Fiber Optic, Cable]
# Contract                       [Two Year, Month-to-Month, One Year]
# Payment Method         [Bank Withdrawal, Credit Card, Mailed Check]
# dtype: object

# %%
X_train = X_train.drop(['Offer','Internet Type','Contract','Payment Method', 'Total Refunds', 'Total Charges',
                        'Total Extra Data Charges','Total Long Distance Charges'],axis=1)

# %%
X_train
# Out:
#       Gender  Age  Married  Number of Dependents  Number of Referrals  \
# 1281       0   23        1                     3                    0
# 2664       1   40        0                     0                    0
# 4633       0   34        0                     0                    0
# 1404       1   46        1                     2                    2
# 5091       1   48        0                     0                    0
# ...      ...  ...      ...                   ...                  ...
# 5466       1   57        1                     1                    1
# 1722       0   38        1                     3                    5
# 4800       1   64        1                     0                    2
# 1944       0   25        0                     1                    0
# 2812       0   49        1                     2                    5
#
#       Tenure in Months  Phone Service  Avg Monthly Long Distance Charges  \
# 1281                24              1                              46.54
# 2664                 1              1                              16.91
# 4633                16              0                               0.00
# 1404                55              1                              24.70
# 5091                 1              1                              27.58
# ...                ...            ...                                ...
# 5466                 5              1                              11.54
# 1722                35              1                              18.86
# 4800                35              1                              23.85
# 1944                49              1                              45.64
# 2812                58              1                              40.74
#
#       Multiple Lines  Internet Service  ...  Offer D  Cable  Fiber  Optic  \
# 1281               1                 0  ...        0      0      0      0
# 2664               0                 0  ...        0      0      0      0
# 4633               0                 0  ...        0      0      0      0
# 1404               0                 0  ...        0      0      0      0
# 5091               0                 0  ...        0      0      0      0
# ...              ...               ...  ...      ...    ...    ...    ...
# 5466               1                 0  ...        0      0      0      0
# 1722               1                 0  ...        0      0      0      0
# 4800               1                 0  ...        0      0      0      0
# 1944               0                 0  ...        0      0      0      0
# 2812               0                 0  ...        0      0      0      0
#
#       DSL  One Year  Two Year  Month-to-Month  Credit Card  Bank Withdrawal
# 1281    1         0         1               0            0                1
# 2664    0         0         0               1            1                0
# 4633    1         0         0               1            0                1
# 1404    0         0         1               0            0                1
# 5091    0         0         0               1            0                1
# ...   ...       ...       ...             ...          ...              ...
# 5466    0         0         0               1            0                1
# 1722    0         0         1               0            0                1
# 4800    0         0         0               1            1                0
# 1944    0         1         0               0            1                0
# 2812    0         0         0               1            0                1
#
# [5538 rows x 36 columns]

# %%
xvar2 = sm.add_constant(X_train)
linearmoderl1 = sm.OLS(y_train, xvar2).fit()
print(linearmoderl1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Total Revenue   R-squared:                       0.917
# Model:                            OLS   Adj. R-squared:                  0.916
# Method:                 Least Squares   F-statistic:                     1952.
# Date:                Tue, 29 Nov 2022   Prob (F-statistic):               0.00
# Time:                        03:01:20   Log-Likelihood:                -45056.
# No. Observations:                5538   AIC:                         9.018e+04
# Df Residuals:                    5506   BIC:                         9.039e+04
# Df Model:                          31
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                             -1835.4859     60.804    -30.187      0.000   -1954.685   -1716.287
# Gender                               13.9357     22.326      0.624      0.533     -29.831      57.703
# Age                                   1.2384      0.838      1.478      0.139      -0.404       2.881
# Married                              70.7013     32.263      2.191      0.028       7.454     133.949
# Number of Dependents                 -1.5700     12.986     -0.121      0.904     -27.029      23.889
# Number of Referrals                  -9.7823      5.215     -1.876      0.061     -20.007       0.442
# Tenure in Months                     82.3960      0.839     98.235      0.000      80.752      84.040
# Phone Service                        34.9241     53.046      0.658      0.510     -69.066     138.915
# Avg Monthly Long Distance Charges    31.8370      0.828     38.472      0.000      30.215      33.459
# Multiple Lines                      176.2453     28.381      6.210      0.000     120.608     231.883
# Internet Service                   1.368e-12   2.45e-13      5.583      0.000    8.88e-13    1.85e-12
# Avg Monthly GB Download              -0.0289      0.764     -0.038      0.970      -1.527       1.469
# Online Security                     205.7273     30.469      6.752      0.000     145.996     265.458
# Online Backup                       327.5761     28.952     11.314      0.000     270.818     384.334
# Device Protection Plan              215.6259     29.929      7.205      0.000     156.953     274.299
# Premium Tech Support                230.6774     30.810      7.487      0.000     170.278     291.077
# Streaming TV                        167.4130     32.686      5.122      0.000     103.336     231.490
# Streaming Movies                    3.78e-13   1.57e-14     24.117      0.000    3.47e-13    4.09e-13
# Streaming Music                      90.7364     31.079      2.920      0.004      29.809     151.664
# Unlimited Data                      -76.7291     35.699     -2.149      0.032    -146.714      -6.745
# Paperless Billing                    -4.3451     25.069     -0.173      0.862     -53.491      44.800
# Monthly Charge                       28.1404      1.112     25.315      0.000      25.961      30.320
# Customer Status                    -208.6699     31.377     -6.650      0.000    -270.181    -147.159
# Offer A                             268.6492     50.275      5.344      0.000     170.090     367.208
# Offer B                             -28.9614     38.595     -0.750      0.453    -104.623      46.700
# Offer C                            -197.7617     48.678     -4.063      0.000    -293.189    -102.334
# Offer E                             169.7276     39.928      4.251      0.000      91.453     248.003
# Offer D                             -72.3807     42.545     -1.701      0.089    -155.786      11.025
# Cable                              -253.6946     43.790     -5.793      0.000    -339.540    -167.849
# Fiber                              5.807e-15   4.22e-15      1.376      0.169   -2.47e-15    1.41e-14
# Optic                              6.887e-15    2.1e-15      3.285      0.001    2.78e-15     1.1e-14
# DSL                                -186.8574     37.874     -4.934      0.000    -261.106    -112.609
# One Year                           -531.5491     28.467    -18.673      0.000    -587.355    -475.743
# Two Year                           -775.7535     31.337    -24.755      0.000    -837.187    -714.320
# Month-to-Month                     -528.1832     26.786    -19.719      0.000    -580.694    -475.672
# Credit Card                        -118.8436     51.326     -2.315      0.021    -219.462     -18.225
# Bank Withdrawal                    -249.6871     51.077     -4.888      0.000    -349.818    -149.556
# ==============================================================================
# Omnibus:                        1.989   Durbin-Watson:                   2.048
# Prob(Omnibus):                  0.370   Jarque-Bera (JB):                1.973
# Skew:                           0.024   Prob(JB):                        0.373
# Kurtosis:                       3.079   Cond. No.                     5.84e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.5e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
summ = linearmoderl1.summary()
summ
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Total Revenue   R-squared:                       0.917
# Model:                            OLS   Adj. R-squared:                  0.916
# Method:                 Least Squares   F-statistic:                     1952.
# Date:                Tue, 29 Nov 2022   Prob (F-statistic):               0.00
# Time:                        03:01:20   Log-Likelihood:                -45056.
# No. Observations:                5538   AIC:                         9.018e+04
# Df Residuals:                    5506   BIC:                         9.039e+04
# Df Model:                          31
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                             -1835.4859     60.804    -30.187      0.000   -1954.685   -1716.287
# Gender                               13.9357     22.326      0.624      0.533     -29.831      57.703
# Age                                   1.2384      0.838      1.478      0.139      -0.404       2.881
# Married                              70.7013     32.263      2.191      0.028       7.454     133.949
# Number of Dependents                 -1.5700     12.986     -0.121      0.904     -27.029      23.889
# Number of Referrals                  -9.7823      5.215     -1.876      0.061     -20.007       0.442
# Tenure in Months                     82.3960      0.839     98.235      0.000      80.752      84.040
# Phone Service                        34.9241     53.046      0.658      0.510     -69.066     138.915
# Avg Monthly Long Distance Charges    31.8370      0.828     38.472      0.000      30.215      33.459
# Multiple Lines                      176.2453     28.381      6.210      0.000     120.608     231.883
# Internet Service                   1.368e-12   2.45e-13      5.583      0.000    8.88e-13    1.85e-12
# Avg Monthly GB Download              -0.0289      0.764     -0.038      0.970      -1.527       1.469
# Online Security                     205.7273     30.469      6.752      0.000     145.996     265.458
# Online Backup                       327.5761     28.952     11.314      0.000     270.818     384.334
# Device Protection Plan              215.6259     29.929      7.205      0.000     156.953     274.299
# Premium Tech Support                230.6774     30.810      7.487      0.000     170.278     291.077
# Streaming TV                        167.4130     32.686      5.122      0.000     103.336     231.490
# Streaming Movies                    3.78e-13   1.57e-14     24.117      0.000    3.47e-13    4.09e-13
# Streaming Music                      90.7364     31.079      2.920      0.004      29.809     151.664
# Unlimited Data                      -76.7291     35.699     -2.149      0.032    -146.714      -6.745
# Paperless Billing                    -4.3451     25.069     -0.173      0.862     -53.491      44.800
# Monthly Charge                       28.1404      1.112     25.315      0.000      25.961      30.320
# Customer Status                    -208.6699     31.377     -6.650      0.000    -270.181    -147.159
# Offer A                             268.6492     50.275      5.344      0.000     170.090     367.208
# Offer B                             -28.9614     38.595     -0.750      0.453    -104.623      46.700
# Offer C                            -197.7617     48.678     -4.063      0.000    -293.189    -102.334
# Offer E                             169.7276     39.928      4.251      0.000      91.453     248.003
# Offer D                             -72.3807     42.545     -1.701      0.089    -155.786      11.025
# Cable                              -253.6946     43.790     -5.793      0.000    -339.540    -167.849
# Fiber                              5.807e-15   4.22e-15      1.376      0.169   -2.47e-15    1.41e-14
# Optic                              6.887e-15    2.1e-15      3.285      0.001    2.78e-15     1.1e-14
# DSL                                -186.8574     37.874     -4.934      0.000    -261.106    -112.609
# One Year                           -531.5491     28.467    -18.673      0.000    -587.355    -475.743
# Two Year                           -775.7535     31.337    -24.755      0.000    -837.187    -714.320
# Month-to-Month                     -528.1832     26.786    -19.719      0.000    -580.694    -475.672
# Credit Card                        -118.8436     51.326     -2.315      0.021    -219.462     -18.225
# Bank Withdrawal                    -249.6871     51.077     -4.888      0.000    -349.818    -149.556
# ==============================================================================
# Omnibus:                        1.989   Durbin-Watson:                   2.048
# Prob(Omnibus):                  0.370   Jarque-Bera (JB):                1.973
# Skew:                           0.024   Prob(JB):                        0.373
# Kurtosis:                       3.079   Cond. No.                     5.84e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.5e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """
